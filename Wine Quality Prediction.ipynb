# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("winequality-red.csv")
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
print(df.dtypes) #Lists all the Attribute Types
print('--------------------------------')
print(df.shape) # Gives the shape of the dataframe (# of rows, # of columns)
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object
# --------------------------------
# (1599, 12)

# %% [markdown]
# # Data Exploration using Statistical Descriptions

# %% [markdown]
# ### Central Tendency Measures
# ###### Finding the mean, median, mode and midrange. We also would like to have an idea of the dispersion of the data, how the data is spread, by finding the range, quartiles and IQR.

# %%
def describe_new(df): #function that adds range, midrange, and IQR to the .describe() table
    df1 = df.describe() #stores  the original .describe() into df1
    df1.loc["range"] = df1.loc['max'] - df1.loc['min'] #creates another row for the ranges
    df1.loc["Midrange"] = (df1.loc['max'] - df1.loc['min']) / 2 #Creates another row for the midrange
    df1.loc["IQR"] = df1.loc['75%'] - df1.loc['25%'] #Creates another row for Interquantile Range
    return df1

describe_new(df)
# Out:
#           fixed acidity  volatile acidity  citric acid  residual sugar  \
# count       1599.000000       1599.000000  1599.000000     1599.000000
# mean           8.319637          0.527821     0.270976        2.538806
# std            1.741096          0.179060     0.194801        1.409928
# min            4.600000          0.120000     0.000000        0.900000
# 25%            7.100000          0.390000     0.090000        1.900000
# 50%            7.900000          0.520000     0.260000        2.200000
# 75%            9.200000          0.640000     0.420000        2.600000
# max           15.900000          1.580000     1.000000       15.500000
# range         11.300000          1.460000     1.000000       14.600000
# Midrange       5.650000          0.730000     0.500000        7.300000
# IQR            2.100000          0.250000     0.330000        0.700000
#
#             chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count     1599.000000          1599.000000           1599.000000  1599.000000
# mean         0.087467            15.874922             46.467792     0.996747
# std          0.047065            10.460157             32.895324     0.001887
# min          0.012000             1.000000              6.000000     0.990070
# 25%          0.070000             7.000000             22.000000     0.995600
# 50%          0.079000            14.000000             38.000000     0.996750
# 75%          0.090000            21.000000             62.000000     0.997835
# max          0.611000            72.000000            289.000000     1.003690
# range        0.599000            71.000000            283.000000     0.013620
# Midrange     0.299500            35.500000            141.500000     0.006810
# IQR          0.020000            14.000000             40.000000     0.002235
#
#                    pH    sulphates      alcohol      quality
# count     1599.000000  1599.000000  1599.000000  1599.000000
# mean         3.311113     0.658149    10.422983     5.636023
# std          0.154386     0.169507     1.065668     0.807569
# min          2.740000     0.330000     8.400000     3.000000
# 25%          3.210000     0.550000     9.500000     5.000000
# 50%          3.310000     0.620000    10.200000     6.000000
# 75%          3.400000     0.730000    11.100000     6.000000
# max          4.010000     2.000000    14.900000     8.000000
# range        1.270000     1.670000     6.500000     5.000000
# Midrange     0.635000     0.835000     3.250000     2.500000
# IQR          0.190000     0.180000     1.600000     1.000000

# %%
df.mode()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.2               0.6          0.0             2.0       0.08
#
#    free sulfur dioxide  total sulfur dioxide  density   pH  sulphates  \
# 0                  6.0                  28.0   0.9972  3.3        0.6
#
#    alcohol  quality
# 0      9.5        5

# %% [markdown]
# ### Skewness
# ###### Measures the deviation of the given distribution of a random variable from a symmetric distribution.

# %%
df.skew()
# Out:
# fixed acidity           0.982751
# volatile acidity        0.671593
# citric acid             0.318337
# residual sugar          4.540655
# chlorides               5.680347
# free sulfur dioxide     1.250567
# total sulfur dioxide    1.515531
# density                 0.071288
# pH                      0.193683
# sulphates               2.428672
# alcohol                 0.860829
# quality                 0.217802
# dtype: float64

# %% [markdown]
# ### Class Imbalance
# ###### How balanced the class values are. So when we have a class imbalance, the machine learning classifier tends to be more biased towards the majority class, causing bad classification of the minority class.

# %%
class_count = df.groupby('quality').size()
class_count
# Out:
# quality
# 3     10
# 4     53
# 5    681
# 6    638
# 7    199
# 8     18
# dtype: int64

# %%
print('3: ', class_count[3]/df['quality'].size)
print('4: ', class_count[4]/df['quality'].size)
print('5: ', class_count[5]/df['quality'].size)
print('6: ', class_count[6]/df['quality'].size)
print('7: ', class_count[7]/df['quality'].size)
print('8: ', class_count[8]/df['quality'].size)
# Out:
# 3:  0.006253908692933083
# 4:  0.03314571607254534
# 5:  0.425891181988743
# 6:  0.3989993746091307
# 7:  0.12445278298936835
# 8:  0.01125703564727955

# %% [markdown]
# ### Correlation
# ###### How one or more attributes are related to each other.

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)
sns.set(rc = {'figure.figsize':(10, 10)})

# %% [markdown]
# # Data Visualization

# %%
sns.scatterplot(data = df, x = "fixed acidity", y = 'pH')
# Out:
# <Axes: xlabel='fixed acidity', ylabel='pH'>

# %%
df1 = df[:5]
df1.plot(df.index.name, ['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','density','pH','sulphates','alcohol','quality'], kind = 'bar')
# Out:
# <Axes: >

# %%
df1 = df[:5]
df1.plot(df.index.name, ['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','density','pH','sulphates','alcohol','quality'], kind = 'barh')
# Out:
# <Axes: >

# %%
df1 = df[:5]
df1.plot(df.index.name, ['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','density','pH','sulphates','alcohol','quality'], kind = 'bar', stacked= True)
# Out:
# <Axes: >

# %%
df1.plot(df.index.name, [1], kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1.plot(df.index.name, [2], kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1.plot(df.index.name, [3], kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1.plot(df.index.name, [4], kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot(kind='hist',subplots=True, layout = (3,3), figsize=(15,8), legend=False, title= ['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','density','pH','sulphates','alcohol','quality'] )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 df.plot(kind='hist',subplots=True, layout = (3,3), figsize=(15,8), legend=False, title= ['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','density','pH','sulphates','alcohol','quality'] )
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_core.py:975, in PlotAccessor.__call__(self, *args, **kwargs)
#     972             label_name = label_kw or data.columns
#     973             data.columns = label_name
# --> 975 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\core.py:447, in MPLPlot.generate(self)
#     445 self._args_adjust()
#     446 self._compute_plot_data()
# --> 447 self._setup_subplots()
#     448 self._make_plot()
#     449 self._add_table()
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\core.py:498, in MPLPlot._setup_subplots(self)
#     494 if self.subplots:
#     495     naxes = (
#     496         self.nseries if isinstance(self.subplots, bool) else len(self.subplots)
#     497     )
# --> 498     fig, axes = create_subplots(
#     499         naxes=naxes,
#     500         sharex=self.sharex,
#     501         sharey=self.sharey,
#     502         figsize=self.figsize,
#     503         ax=self.ax,
#     504         layout=self.layout,
#     505         layout_type=self._layout_type,
#     506     )
#     507 else:
#     508     if self.ax is None:
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\tools.py:267, in create_subplots(naxes, sharex, sharey, squeeze, subplot_kw, ax, layout, layout_type, **fig_kw)
#     259         warnings.warn(
#     260             "To output multiple subplots, the figure containing "
#     261             "the passed axes is being cleared.",
#     262             UserWarning,
#     263             stacklevel=find_stack_level(),
#     264         )
#     265         fig.clear()
# --> 267 nrows, ncols = _get_layout(naxes, layout=layout, layout_type=layout_type)
#     268 nplots = nrows * ncols
#     270 # Create empty object array to hold all axes.  It's easiest to make it 1-d
#     271 # so we can just append subplots upon creation, and then
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\tools.py:103, in _get_layout(nplots, layout, layout_type)
#     100         raise ValueError(msg)
#     102     if nrows * ncols < nplots:
# --> 103         raise ValueError(
#     104             f"Layout of {nrows}x{ncols} must be larger than required size {nplots}"
#     105         )
#     107     return layout
#     109 if layout_type == "single":
#
# ValueError: Layout of 3x3 must be larger than required size 12

# %%
df1.plot(df.index.name, [5], kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1.plot(df.index.name, [6], kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1.plot(df.index.name, [7], kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1.plot(df.index.name, [8], kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1.plot(df.index.name, [9], kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1.plot(df.index.name, [10], kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1.plot(df.index.name, [11], kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1.plot(df.index.name, [12], kind = 'hist')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 df1.plot(df.index.name, [12], kind = 'hist')
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_core.py:948, in PlotAccessor.__call__(self, *args, **kwargs)
#     946 int_y_arg = is_integer(y) or int_ylist
#     947 if int_y_arg and not data.columns._holds_integer():
# --> 948     y = data_cols[y]
#     950 label_kw = kwargs["label"] if "label" in kwargs else False
#     951 for kw in ["xerr", "yerr"]:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5196, in Index.__getitem__(self, key)
#    5193     else:
#    5194         key = np.asarray(key, dtype=bool)
# -> 5196 result = getitem(key)
#    5197 # Because we ruled out integer above, we always get an arraylike here
#    5198 if result.ndim > 1:
#
# IndexError: index 12 is out of bounds for axis 0 with size 12

# %%
df.plot(kind = 'hist',subplots=True, layout = (3,3), figsize=(15,8), legend=False, title = ['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','density','pH','sulphates','alcohol','quality'] )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 df.plot(kind = 'hist',subplots=True, layout = (3,3), figsize=(15,8), legend=False, title = ['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','density','pH','sulphates','alcohol','quality'] )
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_core.py:975, in PlotAccessor.__call__(self, *args, **kwargs)
#     972             label_name = label_kw or data.columns
#     973             data.columns = label_name
# --> 975 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\core.py:447, in MPLPlot.generate(self)
#     445 self._args_adjust()
#     446 self._compute_plot_data()
# --> 447 self._setup_subplots()
#     448 self._make_plot()
#     449 self._add_table()
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\core.py:498, in MPLPlot._setup_subplots(self)
#     494 if self.subplots:
#     495     naxes = (
#     496         self.nseries if isinstance(self.subplots, bool) else len(self.subplots)
#     497     )
# --> 498     fig, axes = create_subplots(
#     499         naxes=naxes,
#     500         sharex=self.sharex,
#     501         sharey=self.sharey,
#     502         figsize=self.figsize,
#     503         ax=self.ax,
#     504         layout=self.layout,
#     505         layout_type=self._layout_type,
#     506     )
#     507 else:
#     508     if self.ax is None:
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\tools.py:267, in create_subplots(naxes, sharex, sharey, squeeze, subplot_kw, ax, layout, layout_type, **fig_kw)
#     259         warnings.warn(
#     260             "To output multiple subplots, the figure containing "
#     261             "the passed axes is being cleared.",
#     262             UserWarning,
#     263             stacklevel=find_stack_level(),
#     264         )
#     265         fig.clear()
# --> 267 nrows, ncols = _get_layout(naxes, layout=layout, layout_type=layout_type)
#     268 nplots = nrows * ncols
#     270 # Create empty object array to hold all axes.  It's easiest to make it 1-d
#     271 # so we can just append subplots upon creation, and then
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\tools.py:103, in _get_layout(nplots, layout, layout_type)
#     100         raise ValueError(msg)
#     102     if nrows * ncols < nplots:
# --> 103         raise ValueError(
#     104             f"Layout of {nrows}x{ncols} must be larger than required size {nplots}"
#     105         )
#     107     return layout
#     109 if layout_type == "single":
#
# ValueError: Layout of 3x3 must be larger than required size 12

# %%
df.plot(df.index.name, ['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','density','pH','sulphates','alcohol','quality'], kind = 'density')
# Out:
# <Axes: ylabel='Density'>

# %%
fig, ax = plt.subplots(figsize=(12, 6))
ax.set_xlim([0, 10])
ax.set_ylim([0, 10])

df.plot(df.index.name, ['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','density','pH','sulphates','alcohol','quality'], kind = 'density')
# Out:
# <Axes: ylabel='Density'>

# %%
df.plot(df.index.name, ['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','density','pH','sulphates','alcohol','quality'], kind = 'kde')
# Out:
# <Axes: ylabel='Density'>

# %%
fig, axes = plt.subplots(2, 3, figsize=(8, 8))#Creates six separate boxplots, 
                                             #figsize enlarges the plots so that it is more visble

sns.scatterplot(df, x = 'quality', y = 'alcohol', ax = axes[0,0])
sns.scatterplot(df, x = 'quality', y = 'volatile acidity', ax = axes[0,1])
sns.scatterplot(df, x = 'density', y = 'alcohol', ax = axes[0,2])
sns.scatterplot(df, x = 'fixed acidity', y = 'density', ax = axes[1,0])
sns.scatterplot(df, x = "fixed acidity", y = 'pH', ax = axes[1,1])
sns.scatterplot(df, x = "volatile acidity", y = 'citric acid', ax = axes[1,2])

fig.tight_layout()

# %%
df.plot(x='quality',y='alcohol', kind='hexbin',color='Blue', gridsize = 10)
# Out:
# <Axes: xlabel='quality', ylabel='alcohol'>

# %%
df.plot(x='quality',y='volatile acidity', kind='hexbin',color='Red', gridsize = 10)
# Out:
# <Axes: xlabel='quality', ylabel='volatile acidity'>

# %%
df.plot(x='density',y='alcohol', kind='hexbin',color='Yellow', gridsize = 10)
# Out:
# <Axes: xlabel='density', ylabel='alcohol'>

# %%
df.plot(x='fixed acidity',y='density', kind='hexbin',color='Orange', gridsize = 10)
# Out:
# <Axes: xlabel='fixed acidity', ylabel='density'>

# %%
df.plot(x='fixed acidity',y='pH', kind='hexbin',color='Red', gridsize = 10)
# Out:
# <Axes: xlabel='fixed acidity', ylabel='pH'>

# %%
df.plot(x='volatile acidity',y='citric acid', kind='hexbin',color='Blue', gridsize = 10)
# Out:
# <Axes: xlabel='volatile acidity', ylabel='citric acid'>
